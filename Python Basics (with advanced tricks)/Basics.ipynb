# %% [markdown]
# ### Python
#
# Python is a high level language that does a lot of things for you.

# %%
# bultin python sort function 
import random 
random.seed(69)

my_list = [random.randint(1,100) for x in range(10)]
print(my_list)

# sorted(list) does not change your list 
print(sorted(my_list))
print(my_list)

# my_list.sort() does not exist

# %% [markdown]
# ![ASCII-Table-wide.svg.png](attachment:ASCII-Table-wide.svg.png)
# Convert between ascii and int

# %%
# chr() converts int to ascii
print(chr(65))

# ord converts ascii to int 
print(ord("A"))
# Out:
# A
# 65

# %% [markdown]
# ### Reading files
# using json and csv modules

# %%
import json 
import csv 


with open("file.json", "r") as jsonfile: 
    data = json.load(jsonfile)

with open("file.csv", "r") as csvfile:
    data = csv.reader(csvfile)

# %% [markdown]
# ### Data types
